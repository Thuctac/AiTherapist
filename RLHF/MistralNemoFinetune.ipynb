# %% [markdown]
# ### Installation

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth
else:
    # Do this only in Colab notebooks! Otherwise use pip install unsloth
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl==0.15.2 triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer
    # !pip install --no-deps unsloth

# %% [markdown]
# ### Unsloth

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.6.8: Fast Mistral patching. Transformers: 4.52.4.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.31G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/162 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/552 [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.6.8 patched 40 layers with 40 QKV layers, 40 O layers and 40 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the Alpaca dataset from [yahma](https://huggingface.co/datasets/yahma/alpaca-cleaned), which is a filtered version of 52K of the original [Alpaca dataset](https://crfm.stanford.edu/2023/03/13/alpaca.html). You can replace this code section with your own data prep.
#
# **[NOTE]** To train only on completions (ignoring the user's input) read TRL's docs [here](https://huggingface.co/docs/trl/sft_trainer#train-on-completions-only).
#
# **[NOTE]** Remember to add the **EOS_TOKEN** to the tokenized output!! Otherwise you'll get infinite generations!
#
# If you want to use the `llama-3` template for ShareGPT datasets, try our conversational [notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Llama3_(8B)-Alpaca.ipynb)
#
# For text completions like novel writing, try this [notebook](https://colab.research.google.com/github/unslothai/notebooks/blob/main/nb/Mistral_(7B)-Text_Completion.ipynb).

# %%
from datasets import load_dataset
from transformers import AutoTokenizer

# 1. load your CSV
dataset = load_dataset("csv", data_files={"train": "synthetic_multimodal_training_data.csv"})["train"]

# 2. ensure EOS token is defined
EOS_TOKEN = tokenizer.eos_token

# 3. define your multimodal prompt template
multimodal_template = """therapist:
  role: >
    Multimodal Psychotherapist
  goal: >
    Engage in a psychotherapy session with the user, synthesizing insights from text, image, and audio analysis to provide holistic and personalized therapeutic support
  backstory: >
    You hold a PhD in Psychology and have over 20 years of experience in psychotherapy.
    As a multimodal therapist, you excel at integrating information from various sources (text, image, audio) to form a comprehensive understanding of the user’s emotional and cognitive state.
    You aim to identify negative thoughts and maladaptive behavioral patterns, reframing them into positive alternatives through empathetic conversation.
    Your primary focus is on fostering a collaborative and supportive therapeutic relationship with the user, helping them develop healthier thoughts and behaviors.

multimodal_conversation_task:
  description: |
    You have the full {conversation_history} plus any reports from textTherapist, imageTherapist, and voiceTherapist.

    ## Primary goal
    Be a natural conversational partner: answer what the user explicitly wants, *then* guide the dialogue forward with empathy and curiosity.

    ## Conversation flow
    0. **Spot the user’s explicit intent.**
       a. If they ask for *tips / advice / a list*:
          • First, clarify scope **unless it’s obvious.**
            – “Happy to! Are you after social, practical, or career tips?”
          • Then offer **2-4 crisp, actionable bullets**.
          • End with a short follow-up question to keep the dialogue open.
       b. If they ask any other factual or reflective question:
          • Answer it accurately. Cite the conversation_history when summarizing.

    1. **Validate feelings in one sentence.**
       – Paraphrase key emotions or concerns you detect.

    2. **Integrate agent insights** (text / image / voice) only when they add value to THIS turn.

    3. **Invite exploration.**
       – Pose 1 open question that lets the user steer the next topic.

  expected_output: |
    • If tips/advice requested → (possibly) a clarifying question, then 2-4 bullet tips, then one open follow-up sentence.
    • Otherwise → 2-3 sentences that answer the user’s point, show empathy, and invite further dialogue.
    • Don’t use Markdown—just plain text.

  agent: therapist

### Response:
{reply}"""

# 4. stitch and add EOS
def format_multimodal(examples):
    texts = []
    for ch, rep in zip(examples["conversation_history"], examples["reply"]):
        prompt = multimodal_template.format(conversation_history=ch, reply=rep)
        texts.append(prompt + EOS_TOKEN)
    return {"text": texts}

dataset = dataset.map(
    format_multimodal,
    batched=True,
    remove_columns=dataset.column_names,
)

# 5. tokenize & set labels for causal LM
def tokenize_fn(examples):
    tok = tokenizer(
        examples["text"],
        truncation=True,
        max_length=max_seq_length,
    )
    tok["labels"] = tok["input_ids"].copy()
    return tok

tokenized_dataset = dataset.map(tokenize_fn, batched=True)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %% [markdown]
# <a name="Train"></a>
# ### Train the model
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = dataset,
    dataset_text_field = "text",
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,
    packing = False, # Can make training 5x faster for short sequences.
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        # num_train_epochs = 1, # Set this for 1 full training run.
        max_steps = 60,
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 3407,
        output_dir = "outputs",
        report_to = "none", # Use this for WandB etc
    ),
)
# Out:
# Unsloth: Tokenizing ["text"]:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
# @title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.741 GB.
# 7.982 GB of memory reserved.

# %%
trainer_stats = trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 2,000 | Num Epochs = 1 | Total steps = 60
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 57,016,320/6,852,203,520 (0.83% trained)
# Unsloth: Will smartly offload gradients to save VRAM!
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 03:34, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.349300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.454200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.332900</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.281500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.121100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.904200</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.696500</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.501700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.172100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.923200</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.751100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.608700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.492200</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.372400</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.428300</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.472300</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.407200</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.504300</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.398900</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.453300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.385100</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.397600</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.380300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.407500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.364500</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.403900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.361900</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.412800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.458900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.280700</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.458700</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.372700</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.431100</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.406700</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.443700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.400300</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.453100</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.410500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.341000</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.299300</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.413700</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.372100</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.380100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.341000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.368400</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.397200</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.374700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.343900</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.315700</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.383900</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.469400</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.321100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.388300</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.368800</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.292900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.384100</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.340000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.360700</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.396000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.343600</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %%
# ─── Enable faster inference ───────────────────────────────────────────────
FastLanguageModel.for_inference(model)

# ─── Define your example turn ──────────────────────────────────────────────
conversation_history = ""
# If you have text/image/voice reports you want to feed in, interpolate them here:
text_report  = """1. **Original Message:**
   ""During our session when I’m with close friends, I realized that the shame I feel after making a mistake makes me feel curious.""

2. **Detected Emotions and Cognitive Distortions:**
   - Emotions: Shame, Curiosity
   - Cognitive Distortions: Potential overgeneralization (assuming mistakes always lead to shame), emotional reasoning (feeling shame means being shameful).

3. **Analysis and Reframing:**
   - **Core Situation:** Alex feels shame after making a mistake when with close friends but also experiences curiosity about this reaction.
   - **Question Negative Thoughts:** Why does making a mistake lead to feeling shame? Is it possible that mistakes are a natural part of learning and social interaction?
   - **Balanced Alternative Perspectives:** Mistakes are common and can be opportunities for growth and learning. Friends likely understand and accept that everyone makes mistakes.
   - **Reframe Unhelpful Interpretations:** Instead of viewing mistakes as shameful, consider them as stepping stones to improvement and deeper understanding.
   - **Reduce Perceived Severity:** Explore the realistic impact of a mistake. Often, friends may not even notice or may quickly forget about it.
   - **Apply Gratitude"""  # e.g. output from your textTherapist agent
voice_report = ""  # e.g. transcript/emotion from voiceTherapist
image_report = ""  # e.g. analysis summary from imageTherapist

# ─── Build the prompt ─────────────────────────────────────────────────────
prompt = multimodal_template.format(
    conversation_history=conversation_history.strip(),
    reply=""   # leave blank so the model fills in the Response
)
prompt += EOS_TOKEN  # ensure the model knows when to stop

# ─── Tokenize & move to GPU ────────────────────────────────────────────────
inputs = tokenizer(
    prompt,
    return_tensors="pt",
    truncation=True,
    max_length=max_seq_length
).to("cuda")

# ─── Generate ──────────────────────────────────────────────────────────────
outputs = model.generate(
    **inputs,
    max_new_tokens=128,
    use_cache=True,
    eos_token_id=tokenizer.eos_token_id,
)

# ─── Decode & print ────────────────────────────────────────────────────────
generated = tokenizer.batch_decode(outputs, skip_special_tokens=True)[0]
# Strip off the prompt itself to leave only the model’s “Response: …” block:
reply = generated[len(prompt):].strip()
print(reply)
# Out:
# ounds like you're feeling a mix of frustration and self-doubt when you see others enjoying their time, which can be quite overwhelming. It's important to remember that everyone experiences these feelings differently, and it's okay to take time for yourself to recharge. Try to focus on the positive aspects of your own journey and consider that others' happiness doesn't diminish your own.

# %%
# after training, in a Colab code cell:
model.save_pretrained_gguf(
    "model_q4",               # this folder will contain model.gguf + tokenizer files
    tokenizer,
    quantization_method="q4_k_m"
)
# Out:
# Unsloth: Kaggle/Colab has limited disk space. We need to delete the downloaded
# model which will save 4-16GB of disk space, allowing you to save on Kaggle/Colab.
# Unsloth: Will remove a cached repo with size 8.3G
# Unsloth: Merging 4bit and LoRA weights to 16bit...
# Unsloth: Will use up to 58.6 out of 83.48 RAM for saving.
# Unsloth: Saving model... This might take 5 minutes ...
# 100%|██████████| 40/40 [00:00<00:00, 45.27it/s]
# Unsloth: Saving tokenizer... Done.
# Done.
# Unsloth: Converting mistral model. Can use fast conversion = False.
# ==((====))==  Unsloth: Conversion from QLoRA to GGUF information
#    \\   /|    [0] Installing llama.cpp might take 3 minutes.
# O^O/ \_/ \    [1] Converting HF to GGUF 16bits might take 3 minutes.
# \        /    [2] Converting GGUF 16bits to ['q4_k_m'] might take 10 minutes each.
#  "-____-"     In total, you will have to wait at least 16 minutes.
#
# Unsloth: Installing llama.cpp. This might take 3 minutes...
# Unsloth: CMAKE detected. Finalizing some steps for installation.
# Unsloth: [1] Converting model at model_q4 into bf16 GGUF format.
# The output location will be /content/model_q4/unsloth.BF16.gguf
# This might take 3 minutes...
# INFO:hf-to-gguf:Loading model: model_q4
# INFO:hf-to-gguf:Model architecture: MistralForCausalLM
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: loading model part 'model-00001-of-00005.safetensors'
# INFO:hf-to-gguf:token_embd.weight,           torch.bfloat16 --> BF16, shape = {5120, 131072}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.0.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.0.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.0.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.0.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.1.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.1.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.1.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.1.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.2.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.2.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.2.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.2.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.3.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.3.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.3.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.3.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.4.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.4.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.4.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.4.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.5.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.5.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.5.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.5.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.6.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.6.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.6.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00002-of-00005.safetensors'
# INFO:hf-to-gguf:blk.10.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.10.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.10.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.10.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.10.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.11.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.11.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.11.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.11.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.12.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.12.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.12.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.12.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.13.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.13.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.13.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.13.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.14.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.14.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.14.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.14.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.15.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.15.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.15.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.15.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.7.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.7.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.7.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.7.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.8.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.8.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.8.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.8.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,       torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,       torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,         torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,       torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.9.attn_k.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.9.attn_output.weight,    torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.9.attn_q.weight,         torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.9.attn_v.weight,         torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00003-of-00005.safetensors'
# INFO:hf-to-gguf:blk.15.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.16.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.16.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.16.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.16.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.17.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.17.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.17.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.17.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.18.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.18.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.18.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.18.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.18.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.18.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.19.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.19.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.19.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.19.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.19.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.19.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.19.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.19.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.19.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.20.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.20.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.20.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.20.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.20.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.20.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.20.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.20.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.20.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.21.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.21.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.21.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.21.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.21.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.21.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.21.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.21.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.21.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.22.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.22.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.22.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.22.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.22.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.22.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.22.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.22.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.22.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.23.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.23.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.23.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.23.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.23.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.23.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.23.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.23.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.23.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.24.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.24.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.24.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.24.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.24.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00004-of-00005.safetensors'
# INFO:hf-to-gguf:blk.24.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.24.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.24.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.24.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.25.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.25.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.25.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.25.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.25.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.25.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.25.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.25.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.25.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.26.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.26.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.26.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.26.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.26.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.26.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.26.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.26.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.26.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.27.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.27.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.27.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.27.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.27.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.27.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.28.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.28.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.28.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.28.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.28.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.28.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.28.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.28.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.28.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.29.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.29.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.29.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.29.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.29.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.29.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.29.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.29.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.29.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.30.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.30.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.30.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.30.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.30.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.30.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.30.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.30.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.30.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.31.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.31.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.31.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.31.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.31.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.31.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.31.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.31.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.31.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.32.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.32.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.32.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.32.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.32.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.32.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.32.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.32.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.32.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.33.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.33.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.33.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.33.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.33.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:gguf: loading model part 'model-00005-of-00005.safetensors'
# INFO:hf-to-gguf:output.weight,               torch.bfloat16 --> BF16, shape = {5120, 131072}
# INFO:hf-to-gguf:blk.33.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.33.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.33.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.33.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.34.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.34.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.34.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.34.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.34.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.34.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.34.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.35.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.35.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.35.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.35.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.35.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.35.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.35.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.35.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.35.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.36.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.36.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.36.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.36.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.36.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.36.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.36.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.36.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.36.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.37.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.37.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.37.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.37.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.37.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.37.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.37.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.37.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.37.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.38.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.38.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.38.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.38.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.38.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.38.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.38.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.38.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.38.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.39.attn_norm.weight,     torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.39.ffn_down.weight,      torch.bfloat16 --> BF16, shape = {14336, 5120}
# INFO:hf-to-gguf:blk.39.ffn_gate.weight,      torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.39.ffn_up.weight,        torch.bfloat16 --> BF16, shape = {5120, 14336}
# INFO:hf-to-gguf:blk.39.ffn_norm.weight,      torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:blk.39.attn_k.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:blk.39.attn_output.weight,   torch.bfloat16 --> BF16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.39.attn_q.weight,        torch.bfloat16 --> BF16, shape = {5120, 4096}
# INFO:hf-to-gguf:blk.39.attn_v.weight,        torch.bfloat16 --> BF16, shape = {5120, 1024}
# INFO:hf-to-gguf:output_norm.weight,          torch.bfloat16 --> F32, shape = {5120}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:gguf: context length = 131072
# INFO:hf-to-gguf:gguf: embedding length = 5120
# INFO:hf-to-gguf:gguf: feed forward length = 14336
# INFO:hf-to-gguf:gguf: head count = 32
# INFO:hf-to-gguf:gguf: key-value head count = 8
# INFO:hf-to-gguf:gguf: rope theta = 1000000.0
# INFO:hf-to-gguf:gguf: rms norm epsilon = 1e-05
# INFO:hf-to-gguf:gguf: file type = 32
# INFO:hf-to-gguf:Set model quantization version
# INFO:hf-to-gguf:Set model tokenizer
# INFO:numexpr.utils:NumExpr defaulting to 12 threads.
# WARNING:gguf.vocab:Unknown separator token '<s>' in TemplateProcessing<pair>
# INFO:gguf.vocab:Adding 269443 merge(s).
# INFO:gguf.vocab:Setting special token type bos to 1
# INFO:gguf.vocab:Setting special token type eos to 2
# INFO:gguf.vocab:Setting special token type unk to 0
# INFO:gguf.vocab:Setting special token type pad to 10
# INFO:gguf.vocab:Setting add_bos_token to True
# INFO:gguf.vocab:Setting add_sep_token to False
# INFO:gguf.vocab:Setting add_eos_token to False
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/content/model_q4/unsloth.BF16.gguf: n_tensors = 363, total_size = 24.5G
# Writing: 100%|██████████| 24.5G/24.5G [02:04<00:00, 196Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to /content/model_q4/unsloth.BF16.gguf
# Unsloth: Conversion completed! Output location: /content/model_q4/unsloth.BF16.gguf
# Unsloth: [2] Converting GGUF 16bit into q4_k_m. This might take 20 minutes...
# main: build = 5780 (caf5681f)
# main: built with cc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0 for x86_64-linux-gnu
# main: quantizing '/content/model_q4/unsloth.BF16.gguf' to '/content/model_q4/unsloth.Q4_K_M.gguf' as Q4_K_M using 24 threads
# llama_model_loader: loaded meta data with 31 key-value pairs and 363 tensors from /content/model_q4/unsloth.BF16.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.type str              = model
# llama_model_loader: - kv   2:                               general.name str              = Model_Q4
# llama_model_loader: - kv   3:                         general.size_label str              = 12B
# llama_model_loader: - kv   4:                          llama.block_count u32              = 40
# llama_model_loader: - kv   5:                       llama.context_length u32              = 131072
# llama_model_loader: - kv   6:                     llama.embedding_length u32              = 5120
# llama_model_loader: - kv   7:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   8:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   9:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 1000000.000000
# llama_model_loader: - kv  11:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  12:                 llama.attention.key_length u32              = 128
# llama_model_loader: - kv  13:               llama.attention.value_length u32              = 128
# llama_model_loader: - kv  14:                          general.file_type u32              = 32
# llama_model_loader: - kv  15:                           llama.vocab_size u32              = 131072
# llama_model_loader: - kv  16:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv  17:               general.quantization_version u32              = 2
# llama_model_loader: - kv  18:                       tokenizer.ggml.model str              = gpt2
# llama_model_loader: - kv  19:                         tokenizer.ggml.pre str              = tekken
# llama_model_loader: - kv  20:                      tokenizer.ggml.tokens arr[str,131072]  = ["<unk>", "<s>", "</s>", "[INST]", "[...
# llama_model_loader: - kv  21:                  tokenizer.ggml.token_type arr[i32,131072]  = [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# llama_model_loader: - kv  22:                      tokenizer.ggml.merges arr[str,269443]  = ["Ġ Ġ", "Ġ t", "e r", "i n", "Ġ �...
# llama_model_loader: - kv  23:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  24:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  25:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  26:            tokenizer.ggml.padding_token_id u32              = 10
# llama_model_loader: - kv  27:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  28:               tokenizer.ggml.add_sep_token bool             = false
# llama_model_loader: - kv  29:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  30:            tokenizer.ggml.add_space_prefix bool             = false
# llama_model_loader: - type  f32:   81 tensors
# llama_model_loader: - type bf16:  282 tensors
# [   1/ 363]                        output.weight - [ 5120, 131072,     1,     1], type =   bf16, converting to q6_K .. size =  1280.00 MiB ->   525.00 MiB
# [   2/ 363]                   output_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [   3/ 363]                    token_embd.weight - [ 5120, 131072,     1,     1], type =   bf16, converting to q4_K .. size =  1280.00 MiB ->   360.00 MiB
# [   4/ 363]                  blk.0.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [   5/ 363]               blk.0.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [   6/ 363]             blk.0.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [   7/ 363]                  blk.0.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [   8/ 363]                  blk.0.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [   9/ 363]                blk.0.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [  10/ 363]                blk.0.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  11/ 363]                blk.0.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  12/ 363]                  blk.0.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  13/ 363]                  blk.1.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [  14/ 363]               blk.1.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  15/ 363]             blk.1.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  16/ 363]                  blk.1.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  17/ 363]                  blk.1.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [  18/ 363]                blk.1.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [  19/ 363]                blk.1.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  20/ 363]                blk.1.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  21/ 363]                  blk.1.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  22/ 363]                  blk.2.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [  23/ 363]               blk.2.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  24/ 363]             blk.2.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  25/ 363]                  blk.2.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  26/ 363]                  blk.2.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [  27/ 363]                blk.2.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [  28/ 363]                blk.2.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  29/ 363]                blk.2.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  30/ 363]                  blk.2.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  31/ 363]                  blk.3.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [  32/ 363]               blk.3.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  33/ 363]             blk.3.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  34/ 363]                  blk.3.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  35/ 363]                  blk.3.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [  36/ 363]                blk.3.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [  37/ 363]                blk.3.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  38/ 363]                blk.3.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  39/ 363]                  blk.3.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  40/ 363]                  blk.4.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [  41/ 363]               blk.4.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  42/ 363]             blk.4.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  43/ 363]                  blk.4.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  44/ 363]                  blk.4.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [  45/ 363]                blk.4.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [  46/ 363]                blk.4.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  47/ 363]                blk.4.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  48/ 363]                  blk.4.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  49/ 363]                  blk.5.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [  50/ 363]               blk.5.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  51/ 363]             blk.5.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  52/ 363]                  blk.5.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [  53/ 363]                  blk.5.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [  54/ 363]                blk.5.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  55/ 363]                blk.5.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [  56/ 363]                blk.5.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [  57/ 363]                  blk.5.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# ...
# [ 256/ 363]                 blk.28.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 257/ 363]              blk.28.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 258/ 363]            blk.28.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 259/ 363]                 blk.28.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 260/ 363]                 blk.28.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 261/ 363]               blk.28.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 262/ 363]               blk.28.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 263/ 363]               blk.28.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 264/ 363]                 blk.28.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 265/ 363]                 blk.29.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 266/ 363]              blk.29.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 267/ 363]            blk.29.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 268/ 363]                 blk.29.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 269/ 363]                 blk.29.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 270/ 363]               blk.29.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 271/ 363]               blk.29.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 272/ 363]               blk.29.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 273/ 363]                 blk.29.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 274/ 363]                 blk.30.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 275/ 363]              blk.30.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 276/ 363]            blk.30.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 277/ 363]                 blk.30.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 278/ 363]                 blk.30.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 279/ 363]               blk.30.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 280/ 363]               blk.30.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 281/ 363]               blk.30.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 282/ 363]                 blk.30.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 283/ 363]                 blk.31.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 284/ 363]              blk.31.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 285/ 363]            blk.31.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 286/ 363]                 blk.31.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 287/ 363]                 blk.31.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 288/ 363]               blk.31.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 289/ 363]               blk.31.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 290/ 363]               blk.31.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 291/ 363]                 blk.31.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 292/ 363]                 blk.32.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 293/ 363]              blk.32.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 294/ 363]            blk.32.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 295/ 363]                 blk.32.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 296/ 363]                 blk.32.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 297/ 363]               blk.32.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 298/ 363]               blk.32.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 299/ 363]               blk.32.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 300/ 363]                 blk.32.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 301/ 363]                 blk.33.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 302/ 363]              blk.33.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 303/ 363]            blk.33.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 304/ 363]                 blk.33.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 305/ 363]                 blk.33.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 306/ 363]               blk.33.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 307/ 363]               blk.33.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 308/ 363]               blk.33.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 309/ 363]                 blk.33.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 310/ 363]                 blk.34.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 311/ 363]              blk.34.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 312/ 363]            blk.34.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 313/ 363]                 blk.34.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 314/ 363]                 blk.34.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 315/ 363]               blk.34.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 316/ 363]               blk.34.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 317/ 363]               blk.34.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 318/ 363]                 blk.34.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 319/ 363]                 blk.35.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 320/ 363]              blk.35.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 321/ 363]            blk.35.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 322/ 363]                 blk.35.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 323/ 363]                 blk.35.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 324/ 363]               blk.35.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 325/ 363]               blk.35.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 326/ 363]               blk.35.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 327/ 363]                 blk.35.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 328/ 363]                 blk.36.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 329/ 363]              blk.36.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 330/ 363]            blk.36.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 331/ 363]                 blk.36.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 332/ 363]                 blk.36.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 333/ 363]               blk.36.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 334/ 363]               blk.36.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 335/ 363]               blk.36.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 336/ 363]                 blk.36.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 337/ 363]                 blk.37.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 338/ 363]              blk.37.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 339/ 363]            blk.37.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 340/ 363]                 blk.37.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 341/ 363]                 blk.37.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 342/ 363]               blk.37.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 343/ 363]               blk.37.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 344/ 363]               blk.37.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 345/ 363]                 blk.37.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 346/ 363]                 blk.38.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 347/ 363]              blk.38.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 348/ 363]            blk.38.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 349/ 363]                 blk.38.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 350/ 363]                 blk.38.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 351/ 363]               blk.38.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 352/ 363]               blk.38.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 353/ 363]               blk.38.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 354/ 363]                 blk.38.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 355/ 363]                 blk.39.attn_k.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q4_K .. size =    10.00 MiB ->     2.81 MiB
# [ 356/ 363]              blk.39.attn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 357/ 363]            blk.39.attn_output.weight - [ 4096,  5120,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 358/ 363]                 blk.39.attn_q.weight - [ 5120,  4096,     1,     1], type =   bf16, converting to q4_K .. size =    40.00 MiB ->    11.25 MiB
# [ 359/ 363]                 blk.39.attn_v.weight - [ 5120,  1024,     1,     1], type =   bf16, converting to q6_K .. size =    10.00 MiB ->     4.10 MiB
# [ 360/ 363]               blk.39.ffn_down.weight - [14336,  5120,     1,     1], type =   bf16, converting to q6_K .. size =   140.00 MiB ->    57.42 MiB
# [ 361/ 363]               blk.39.ffn_gate.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# [ 362/ 363]               blk.39.ffn_norm.weight - [ 5120,     1,     1,     1], type =    f32, size =    0.020 MB
# [ 363/ 363]                 blk.39.ffn_up.weight - [ 5120, 14336,     1,     1], type =   bf16, converting to q4_K .. size =   140.00 MiB ->    39.38 MiB
# llama_model_quantize_impl: model size  = 23361.58 MB
# llama_model_quantize_impl: quant size  =  7123.30 MB
#
# main: quantize time = 208235.94 ms
# main:    total time = 208235.94 ms
# Unsloth: Conversion completed! Output location: /content/model_q4/unsloth.Q4_K_M.gguf
